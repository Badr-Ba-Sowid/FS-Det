# %%
import numpy as np

# %%
data = np.load("../data/model_net_40c/data_original.npy")
data
# Out:
# array([[[ 0.11473347, -0.24852079, -0.2110258 ],
#         [-0.15823308,  0.76384324,  0.09794946],
#         [ 0.27286473,  0.0562073 , -0.07415426],
#         ...,
#         [-0.43141243,  0.5920765 , -0.12651369],
#         [-0.43141243,  0.4525703 ,  0.02377603],
#         [-0.09790168, -0.3918829 ,  0.09173188]],
#
#        [[-0.19705865, -0.08851751, -0.27409643],
#         [-0.00631129,  0.20328109,  0.76495105],
#         [ 0.11568195, -0.13632657, -0.11351562],
#         ...,
#         [ 0.06273329,  0.06613805, -0.5731614 ],
#         [-0.08901567,  0.02209834,  0.0429598 ],
#         [ 0.38708743, -0.0023525 , -0.04952602]],
#
#        [[-0.45509875,  0.00848014, -0.02495196],
#         [ 0.10803173,  0.01803044, -0.22894876],
#         [ 0.19881994,  0.19499797,  0.56901485],
#         ...,
#         [ 0.13512343,  0.02565328, -0.7387579 ],
#         [-0.2915578 ,  0.14287281,  0.57508785],
#         [ 0.07596319, -0.1837407 ,  0.74524057]],
#
#        ...,
#
# ...

# %%
data.shape
# Out:
# (2468, 1024, 3)
